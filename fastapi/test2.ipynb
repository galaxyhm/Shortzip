# %%
from bs4 import BeautifulSoup
import requests
import re
import sys
import pprint
import csv
import json

# %%
headers = {
    'authority': 'apis.naver.com',
    'accept': '*/*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    # Requests sorts cookies= alphabetically
    # 'cookie': 'ab.storage.userId.7af503ae-0c84-478f-98b0-ecfff5d67750=%7B%22g%22%3A%22browser-1625985144309-6%22%2C%22c%22%3A1626101500089%2C%22l%22%3A1626101500089%7D; ab.storage.deviceId.7af503ae-0c84-478f-98b0-ecfff5d67750=%7B%22g%22%3A%224cbe130c-6edd-d4aa-a78d-290b003c3592%22%2C%22c%22%3A1626101500094%2C%22l%22%3A1626101500094%7D; ASID=7992e0220000017aaa36664e0000004e; _ga=GA1.2.612969395.1626832328; ab.storage.sessionId.7af503ae-0c84-478f-98b0-ecfff5d67750=%7B%22g%22%3A%2228148006-e01d-7623-b7d1-b4fff0f59b4e%22%2C%22e%22%3A1627919390179%2C%22c%22%3A1627908091281%2C%22l%22%3A1627917590179%7D; MM_NEW=1; NFS=2; NNB=RDIIILNX6JCWE; nx_ssl=2; nid_inf=1665554565; NID_AUT=tP3V5ox533EjyAgkJ1JaqWEnPOhXs2hr3teD39pK972fuXqDWQZXoIOMzICJpa1A; NID_JKL=d393brIzilbjw+7TVvG0OW6Eo22+WIhQAfihItUdgbY=; _naver_usersession_=SPdJTrlTMrn8Udkyn58eo6HL; NID_SES=...; NDARK=N; page_uid=hrKUflprvN8ssNc4Muwssssss3R-382317; BMR=',
    'referer': 'https://n.news.naver.com/article/028/0002595736',
    'sec-ch-ua': '"Whale";v="3", " Not;A Brand";v="99", "Chromium";v="102"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'script',
    'sec-fetch-mode': 'no-cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.108 Whale/3.15.136.18 Safari/537.36',
}

# %%
params = {
                'ticket': 'news',
                'templateId': 'default_society',
                'pool': 'cbox5',
                'lang': 'ko',
                'country': 'KR',
                'objectId': 'news018,0005477530', #f'news{oid_2},{oid_1}',
                'pageSize': '100',
                'indexSize': '10',
                'page': '1',
                'currentPage': '0',
                'moreParam.direction': 'next',
                'moreParam.prev': '10000o90000op06guicil48ars',
                'moreParam.next': '1000050000305guog893h1re',
                'followSize': '100',
                'includeAllStatus': 'true',
                'sort' : 'favorite'
            }

# %%
response = requests.get('https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json', params=params, headers=headers)

# %%
response.encoding = "UTF-8-sig"

# %%
res = response.text.replace("_callback(","")[:-2]
temp=json.loads(res)

# %%
temp
# Out:
# {'success': True,
#  'code': '1000',
#  'message': '요청을 성공적으로 처리하였습니다.',
#  'lang': 'ko',
#  'country': 'KR',
#  'result': {'commentList': [{'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790684449149813072',
#     'parentCommentNo': '790684449149813072',
#     'replyLevel': 1,
#     'replyCount': 49,
#     'replyAllCount': 49,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683067076799,
#     'contents': '옛날 80~90년대는 공무원 하라고해도 하는사람 없었음.  얼마나 하는 사람이 없으면 읍,면,동장이 적합한 인재있으면 추천해줘서 공무원되고 그런 시절이 있었지... 소개팅이나 맞선 시장에서 쳐주지도 안했다더라.  어떻게보면 정상적으로 돌아가고 있는거',
#     'userIdNo': '4bfAA',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'nobl****',
#     'userProfileImage': 'https://phinf.pstatic.net/contact/20190508_58/1557304706337vcRui_JPEG/KakaoTalk_20190221_131524236.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-05-03T07:37:56+0900',
#     'modTimeGmt': '2023-05-02T22:37:56+0000',
#     'regTime': '2023-05-03T07:37:56+0900',
#     'regTimeGmt': '2023-05-02T22:37:56+0000',
#     'sympathyCount': 767,
#     'antipathyCount': 101,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '4bfAA',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'nobl****',
#     'maskedUserName': 'no****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790686872937431204',
#     'parentCommentNo': '790686872937431204',
#     'replyLevel': 1,
#     'replyCount': 24,
#     'replyAllCount': 24,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683069334045,
#     'contents': '공무원을 왜 하냐\n월급도 적지 연금도 바닥이고\n\n자기 발전도\n 없구',
#     'userIdNo': '1XNEl',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'dk30****',
#     'userProfileImage': 'https://phinf.pstatic.net/contact/20160528_83/1464427382150ucCAT_PNG/avatar_profile.png',
#     'profileType': 'naver',
#     'modTime': '2023-05-03T08:15:34+0900',
#     'modTimeGmt': '2023-05-02T23:15:34+0000',
#     'regTime': '2023-05-03T08:15:34+0900',
#     'regTimeGmt': '2023-05-02T23:15:34+0000',
#     'sympathyCount': 270,
#     'antipathyCount': 25,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '1XNEl',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'dk30****',
#     'maskedUserName': 'dk****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790684392560263183',
#     'parentCommentNo': '790684392560263183',
#     'replyLevel': 1,
#     'replyCount': 11,
#     'replyAllCount': 11,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683067024557,
#     'contents': '공무원합격은 귄성0',
#     'userIdNo': '8pJj',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'see_****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T07:37:04+0900',
#     'modTimeGmt': '2023-05-02T22:37:04+0000',
#     'regTime': '2023-05-03T07:37:04+0900',
#     'regTimeGmt': '2023-05-02T22:37:04+0000',
#     'sympathyCount': 233,
#     'antipathyCount': 37,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '8pJj',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'see_****',
#     'maskedUserName': 'se****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790685293597425678',
#     'parentCommentNo': '790685293597425678',
#     'replyLevel': 1,
#     'replyCount': 5,
#     'replyAllCount': 5,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683067863000,
#     'contents': '뭘 어떻게 했길래 빚이 쌓이냐?? 그간 공시생들 돈 쪽쪽 빨았을텐데???',
#     'userIdNo': '4LZsr',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'cksg****',
#     'userProfileImage': 'https://phinf.pstatic.net/contact/20221129_295/1669714353766k9XAo_PNG/avatar_profile.png',
#     'profileType': 'naver',
#     'modTime': '2023-05-03T07:51:03+0900',
#     'modTimeGmt': '2023-05-02T22:51:03+0000',
#     'regTime': '2023-05-03T07:51:03+0900',
#     'regTimeGmt': '2023-05-02T22:51:03+0000',
#     'sympathyCount': 132,
#     'antipathyCount': 4,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '4LZsr',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'cksg****',
#     'maskedUserName': 'ck****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790688082843140214',
#     'parentCommentNo': '790688082843140214',
#     'replyLevel': 1,
#     'replyCount': 6,
#     'replyAllCount': 6,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683070461145,
#     'contents': '공무원은 하면 안된다.일이 편한것도 아니고, 잦은 부서 이동으로 10년간 신규처럼 일해야 된다. 민선제의 혼돈으로 인해 시군구청장이 재선을 위해 쓸데없는 일 엄청 만든다.그리고 각 시의원들이 보좌관 둘 수 있어서 공무원한테 자료요구 엄청나고, 스마트한 시민과 악성 민원으로 항상 시달리며 30년 해도 월 5~600  가량 이다. 누군가에겐 크지만 누군가에겐 10년차면 가져갈 금액이지. 마지막으로 남은연금도 65세 이상 돼야 받을수 있고 ,정년은 60세라서 5년간 손 빨아야됨. 연금은 국민연금',
#     'userIdNo': 'M5eX',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'jung****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T08:34:21+0900',
#     'modTimeGmt': '2023-05-02T23:34:21+0000',
#     'regTime': '2023-05-03T08:34:21+0900',
#     'regTimeGmt': '2023-05-02T23:34:21+0000',
#     'sympathyCount': 110,
#     'antipathyCount': 5,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': 'M5eX',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'jung****',
#     'maskedUserName': 'ju****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790683809988214791',
#     'parentCommentNo': '790683809988214791',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683066481262,
#     'contents': '유명강사들 다른학원 이직하는거보고 뭔가 쎄한 느낌들던데..역쉬.',
#     'userIdNo': '1Edt8',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'yws1****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T07:28:01+0900',
#     'modTimeGmt': '2023-05-02T22:28:01+0000',
#     'regTime': '2023-05-03T07:28:01+0900',
#     'regTimeGmt': '2023-05-02T22:28:01+0000',
#     'sympathyCount': 65,
#     'antipathyCount': 5,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '1Edt8',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'yws1****',
#     'maskedUserName': 'yw****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790693254185091332',
#     'parentCommentNo': '790693254185091332',
#     'replyLevel': 1,
#     'replyCount': 1,
#     'replyAllCount': 1,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683075277207,
#     'contents': '공무원보다 국회의원놈들 월급을 최저시급으로 깎아야된다.',
#     'userIdNo': '1FZpG',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'haow****',
#     'userProfileImage': 'https://phinf.pstatic.net/contact/20200320_19/1584632311924nfy4V_PNG/avatar_profile.png',
#     'profileType': 'naver',
#     'modTime': '2023-05-03T09:54:37+0900',
#     'modTimeGmt': '2023-05-03T00:54:37+0000',
#     'regTime': '2023-05-03T09:54:37+0900',
#     'regTimeGmt': '2023-05-03T00:54:37+0000',
#     'sympathyCount': 45,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '1FZpG',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'haow****',
#     'maskedUserName': 'ha****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790693657945571728',
#     'parentCommentNo': '790693657945571728',
#     'replyLevel': 1,
#     'replyCount': 1,
#     'replyAllCount': 1,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683075653824,
#     'contents': '월급 500받는 사람처럼 업무, 욕받이 시키는데 월급은 최저임금주고 남들은 몇억씩 챙겨나가는 퇴직금조차 못받고 연금은 개박살나서 국민연금이랑 별차이도 없는수준까지 내려왔는데 도대체 아무런 메리트가 없는 직업인데 할 이유가 없잖아...',
#     'userIdNo': '37fW7',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'canu****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T10:00:53+0900',
#     'modTimeGmt': '2023-05-03T01:00:53+0000',
#     'regTime': '2023-05-03T10:00:53+0900',
#     'regTimeGmt': '2023-05-03T01:00:53+0000',
#     'sympathyCount': 43,
#     'antipathyCount': 3,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '37fW7',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'canu****',
#     'maskedUserName': 'ca****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790696553558835632',
#     'parentCommentNo': '790696553558835632',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683078350131,
#     'contents': '공무원 요즘 하고 싶어 하겠냐? 그나마 바라볼 공무원연금도 반토막 났는데. 차라리 국민연금을 달라 하는 공무원들이 태반이다. 박봉이고. 그렇다고 워라벨을 챙기나? 칼퇴하는 공무원은 일부고, 일에 시달려서 늦게 퇴근한다. 인수인계도 잘 안 되고, 전 근무자가 다음 근무자 죽어보라고 컴퓨터 가져가는 경우도 있다. 거기다 철밥통이라고 윗사람도 안 잘리는데 그 사람이 진상이면, 그냥 계속 봐야 한다. 거기다 군대마냥 상하관계 심하고. 그러니 공무원 시험 힘들게 하고 몇 달 다니다 나가거나, 버티다 힘들어서 자살하는 경우가 많다. 짠하다.',
#     'userIdNo': '12A0r',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'kse5****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T10:45:50+0900',
#     'modTimeGmt': '2023-05-03T01:45:50+0000',
#     'regTime': '2023-05-03T10:45:50+0900',
#     'regTimeGmt': '2023-05-03T01:45:50+0000',
#     'sympathyCount': 41,
#     'antipathyCount': 3,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '12A0r',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'kse5****',
#     'maskedUserName': 'ks****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790685561244352572',
#     'parentCommentNo': '790685561244352572',
#     'replyLevel': 1,
#     'replyCount': 2,
#     'replyAllCount': 2,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683068112817,
#     'contents': '문재인 정권때 공무원 수 엄청 늘리더니 결국 이꼴 남',
#     'userIdNo': '2CQ6r',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'dead****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T07:55:12+0900',
#     'modTimeGmt': '2023-05-02T22:55:12+0000',
#     'regTime': '2023-05-03T07:55:12+0900',
#     'regTimeGmt': '2023-05-02T22:55:12+0000',
#     'sympathyCount': 42,
#     'antipathyCount': 12,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '2CQ6r',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'dead****',
#     'maskedUserName': 'de****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790694785743585474',
#     'parentCommentNo': '790694785743585474',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683076703098,
#     'contents': '어차피 별볼일 없는 허수들만 빠진거고 경쟁은 여전히 치열함ㅋㅋ',
#     'userIdNo': '2rv8y',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'qed1****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T10:18:23+0900',
#     'modTimeGmt': '2023-05-03T01:18:23+0000',
#     'regTime': '2023-05-03T10:18:23+0900',
#     'regTimeGmt': '2023-05-03T01:18:23+0000',
#     'sympathyCount': 28,
#     'antipathyCount': 2,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '2rv8y',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'qed1****',
#     'maskedUserName': 'qe****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790685632715292758',
#     'parentCommentNo': '790685632715292758',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683068179986,
#     'contents': '매출에 비해 마케팅 과하게하는 특히 유명연예인에 의존하는 기업과 제품은 걸러야한다. 연예인, 인플루언서, 방송ppl에 놀아나지마라.',
#     'userIdNo': '5O30A',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'youn****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T07:56:19+0900',
#     'modTimeGmt': '2023-05-02T22:56:19+0000',
#     'regTime': '2023-05-03T07:56:19+0900',
#     'regTimeGmt': '2023-05-02T22:56:19+0000',
#     'sympathyCount': 24,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '5O30A',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'youn****',
#     'maskedUserName': 'yo****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790695149322633240',
#     'parentCommentNo': '790695149322633240',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683077042908,
#     'contents': '그래도 공무원이 젤 속편함..',
#     'userIdNo': '1ZrST',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'hyun****',
#     'userProfileImage': 'https://phinf.pstatic.net/contact/20170606_164/1496753719250QInXw_PNG/avatar_profile.png',
#     'profileType': 'naver',
#     'modTime': '2023-05-03T10:24:02+0900',
#     'modTimeGmt': '2023-05-03T01:24:02+0000',
#     'regTime': '2023-05-03T10:24:02+0900',
#     'regTimeGmt': '2023-05-03T01:24:02+0000',
#     'sympathyCount': 21,
#     'antipathyCount': 3,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '1ZrST',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'hyun****',
#     'maskedUserName': 'hy****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790687737182159171',
#     'parentCommentNo': '790687737182159171',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683070139118,
#     'contents': '내실없이 너무 사업을 무리해서 확장해나가니 이런 사단이 벌어진 거임. 딱 공인중개사와 주택관리사만 하고 다른 것은 손대지 말았어야 함. 다른 자격증이나 공무원 합격자들 대부분 에듀윌로는 공부 잘 안함.',
#     'userIdNo': '1WIjZ',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'star****',
#     'userProfileImage': 'https://phinf.pstatic.net/contact/20190602_189/1559480101926ieUt7_PNG/avatar_profile.png',
#     'profileType': 'naver',
#     'modTime': '2023-05-03T08:28:59+0900',
#     'modTimeGmt': '2023-05-02T23:28:59+0000',
#     'regTime': '2023-05-03T08:28:59+0900',
#     'regTimeGmt': '2023-05-02T23:28:59+0000',
#     'sympathyCount': 18,
#     'antipathyCount': 0,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '1WIjZ',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'star****',
#     'maskedUserName': 'st****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790689260536594674',
#     'parentCommentNo': '790689260536594674',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683071557444,
#     'contents': '공기업  일반회사보다  일은힘들고  월급은  적게주니  점점인기가  없어진다  그보상으로  퇴직후  연금을  받는건데  그것도  깍으라고  난리고  점점\n의욕이  없어 질수 밖에없다',
#     'userIdNo': '6loGF',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'shbb****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T08:52:37+0900',
#     'modTimeGmt': '2023-05-02T23:52:37+0000',
#     'regTime': '2023-05-03T08:52:37+0900',
#     'regTimeGmt': '2023-05-02T23:52:37+0000',
#     'sympathyCount': 19,
#     'antipathyCount': 2,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '6loGF',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'shbb****',
#     'maskedUserName': 'sh****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790701884317892886',
#     'parentCommentNo': '790701884317892886',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683083314267,
#     'contents': '공무원이지만 진짜 할 게 아닙니다. 박봉에 책임은 엄청많고 얼마나 제약이 많은지요.',
#     'userIdNo': '2JZNu',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'blue****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T12:08:34+0900',
#     'modTimeGmt': '2023-05-03T03:08:34+0000',
#     'regTime': '2023-05-03T12:08:34+0900',
#     'regTimeGmt': '2023-05-03T03:08:34+0000',
#     'sympathyCount': 18,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '2JZNu',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'blue****',
#     'maskedUserName': 'bl****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790696063093702767',
#     'parentCommentNo': '790696063093702767',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683077893003,
#     'contents': '공무원이라는 직업 그렇게 좋은 직업이 아니다. 첫번째 늘 야근을 하지만 초과근무 수당을 정당하게 받지 못한다. 일반공무원 경우 일일 4시간 적용되기 때문에 휴일날 초과근무을 4시간이상 하여도 동일하게 4시간만 인정되고 지급받는다. 두번째 공무원 연금은 각 개인 급여 9.8% 그리고 각 소득세, 건강보험 등 공제된다. 그럼 실수령액은 얼마 일 것 같습니까?.  공무원 연금 이제 국민연금 수준으로 노후대책이 되지 않는다. 모두다 옛말이다.',
#     'userIdNo': 'UpQC',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'haha****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T10:38:13+0900',
#     'modTimeGmt': '2023-05-03T01:38:13+0000',
#     'regTime': '2023-05-03T10:38:13+0900',
#     'regTimeGmt': '2023-05-03T01:38:13+0000',
#     'sympathyCount': 17,
#     'antipathyCount': 4,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': 'UpQC',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'haha****',
#     'maskedUserName': 'ha****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790698385060397177',
#     'parentCommentNo': '790698385060397177',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683080055975,
#     'contents': '편의점 야간 알바가 훨씬 많이 버는데 누가 공무원을 함ㅋㅋ',
#     'userIdNo': '37pRP',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'sunn****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T11:14:15+0900',
#     'modTimeGmt': '2023-05-03T02:14:15+0000',
#     'regTime': '2023-05-03T11:14:15+0900',
#     'regTimeGmt': '2023-05-03T02:14:15+0000',
#     'sympathyCount': 15,
#     'antipathyCount': 3,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '37pRP',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'sunn****',
#     'maskedUserName': 'su****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790696844240879786',
#     'parentCommentNo': '790696844240879786',
#     'replyLevel': 1,
#     'replyCount': 1,
#     'replyAllCount': 1,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683078620516,
#     'contents': '1000명에게 물어 봤더니....중소기업 갈래...공무원 할래...질문 했습니다...결과는 중소기업 17.5%  공무원 78.4 %  기타 4.1%  로 나왔습니다  ..그래도 공무원을 선택합니다',
#     'userIdNo': 'd8Vef',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'hswo****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T10:50:20+0900',
#     'modTimeGmt': '2023-05-03T01:50:20+0000',
#     'regTime': '2023-05-03T10:50:20+0900',
#     'regTimeGmt': '2023-05-03T01:50:20+0000',
#     'sympathyCount': 12,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': 'd8Vef',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'hswo****',
#     'maskedUserName': 'hs****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790689526187032833',
#     'parentCommentNo': '790689526187032833',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683071805169,
#     'contents': '권성동 한테 원생 다 뺐겨서 망한듯',
#     'userIdNo': '4ICUL',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '7796****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T08:56:45+0900',
#     'modTimeGmt': '2023-05-02T23:56:45+0000',
#     'regTime': '2023-05-03T08:56:45+0900',
#     'regTimeGmt': '2023-05-02T23:56:45+0000',
#     'sympathyCount': 15,
#     'antipathyCount': 5,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '4ICUL',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': '7796****',
#     'maskedUserName': '77****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790690811640545547',
#     'parentCommentNo': '790690811640545547',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683073002769,
#     'contents': '공무원하면 먹고살기 힘들어요',
#     'userIdNo': '2Pp6f',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 't100****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T09:16:42+0900',
#     'modTimeGmt': '2023-05-03T00:16:42+0000',
#     'regTime': '2023-05-03T09:16:42+0900',
#     'regTimeGmt': '2023-05-03T00:16:42+0000',
#     'sympathyCount': 10,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
# ...
#     'idProvider': 'naver',
#     'userName': 'dana****',
#     'userProfileImage': 'https://phinf.pstatic.net/contact/2/2011/9/9/danamu93_1315579529238.png',
#     'profileType': 'naver',
#     'modTime': '2023-05-03T10:14:45+0900',
#     'modTimeGmt': '2023-05-03T01:14:45+0000',
#     'regTime': '2023-05-03T10:14:45+0900',
#     'regTimeGmt': '2023-05-03T01:14:45+0000',
#     'sympathyCount': 4,
#     'antipathyCount': 4,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': 'KG6M',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'dana****',
#     'maskedUserName': 'da****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790692598934143152',
#     'parentCommentNo': '790692598934143152',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683074666734,
#     'contents': '고3 학생이 한때 100만명이었다가, 지금은 30만명.  앞으로 10만명이 얼마 안남았다.  출생율 0.7명의 한국여자가 그저 한심하고 대단하다',
#     'userIdNo': 'Iih1',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'pali****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T09:44:26+0900',
#     'modTimeGmt': '2023-05-03T00:44:26+0000',
#     'regTime': '2023-05-03T09:44:26+0900',
#     'regTimeGmt': '2023-05-03T00:44:26+0000',
#     'sympathyCount': 3,
#     'antipathyCount': 3,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': 'Iih1',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'pali****',
#     'maskedUserName': 'pa****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790710002863046957',
#     'parentCommentNo': '790710002863046957',
#     'replyLevel': 1,
#     'replyCount': 2,
#     'replyAllCount': 2,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683090875901,
#     'contents': '진짜 인생실패한 사람들이나 공무원 준비하더라 요새',
#     'userIdNo': '2RmDw',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'wjdt****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T14:14:35+0900',
#     'modTimeGmt': '2023-05-03T05:14:35+0000',
#     'regTime': '2023-05-03T14:14:35+0900',
#     'regTimeGmt': '2023-05-03T05:14:35+0000',
#     'sympathyCount': 2,
#     'antipathyCount': 2,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '2RmDw',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'wjdt****',
#     'maskedUserName': 'wj****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790690313323675988',
#     'parentCommentNo': '790690313323675988',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683072538948,
#     'contents': '9급 공무원은 할 사람만 하자~~ 고급인력들이 동사무소서 등본이나 발급하고 있다는건 국가적으로 손해다~',
#     'userIdNo': '2LJHa',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'mira****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T09:08:58+0900',
#     'modTimeGmt': '2023-05-03T00:08:58+0000',
#     'regTime': '2023-05-03T09:08:58+0900',
#     'regTimeGmt': '2023-05-03T00:08:58+0000',
#     'sympathyCount': 2,
#     'antipathyCount': 2,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '2LJHa',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'mira****',
#     'maskedUserName': 'mi****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790712623984279717',
#     'parentCommentNo': '790712623984279717',
#     'replyLevel': 1,
#     'replyCount': 1,
#     'replyAllCount': 1,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683093316890,
#     'contents': '왜 항상 가만히 있는 공무원만 머리채 잡고 닌리들이냐…ㅋㅋㅋ 부러워서 그러는 거임? 그게 아니면 도대체 왜? 남의 직업 까내리면서 본인이 더 우월하다고 느낀다면 참 불쌍한 인생들이다 얼마나 자존감이 없으면',
#     'userIdNo': '1B8ba',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'sk98****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T14:55:16+0900',
#     'modTimeGmt': '2023-05-03T05:55:16+0000',
#     'regTime': '2023-05-03T14:55:16+0900',
#     'regTimeGmt': '2023-05-03T05:55:16+0000',
#     'sympathyCount': 1,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '1B8ba',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'sk98****',
#     'maskedUserName': 'sk****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790708019578011979',
#     'parentCommentNo': '790708019578011979',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683089028258,
#     'contents': '9급공채 공무원은 그냥 중졸,고졸 기타 사회취약계층들만 할수 있게 못박아야 한다고 봄. 전문대,4년제대 졸업한 사람들이 하는건 너무 인력낭비라 생각함.',
#     'userIdNo': 'bGVpW',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'last****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T13:43:48+0900',
#     'modTimeGmt': '2023-05-03T04:43:48+0000',
#     'regTime': '2023-05-03T13:43:48+0900',
#     'regTimeGmt': '2023-05-03T04:43:48+0000',
#     'sympathyCount': 1,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': 'bGVpW',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'last****',
#     'maskedUserName': 'la****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790705234895700220',
#     'parentCommentNo': '790705234895700220',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683086435694,
#     'contents': '성동이형이 있는데 에듀윌 따위가 뭐라고 감히…',
#     'userIdNo': '34NGY',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'simo****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T13:00:35+0900',
#     'modTimeGmt': '2023-05-03T04:00:35+0000',
#     'regTime': '2023-05-03T13:00:35+0900',
#     'regTimeGmt': '2023-05-03T04:00:35+0000',
#     'sympathyCount': 1,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '34NGY',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'simo****',
#     'maskedUserName': 'si****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False}],
#   'pageModel': {'page': 1,
#    'pageSize': 100,
#    'indexSize': 10,
#    'startRow': 1,
#    'endRow': 100,
#    'totalRows': 259,
#    'startIndex': 0,
#    'totalPages': 3,
#    'firstPage': 1,
#    'prevPage': 0,
#    'nextPage': 2,
#    'lastPage': 3,
#    'current': None,
#    'threshold': None,
#    'moveToLastPage': False,
#    'moveToComment': False,
#    'moveToLastPrev': False},
#   'morePage': {'prev': '10000o90000op06guicil48ars',
#    'next': '10000000000010609lm298q3ng',
#    'start': '10000ii0000lb0609e8tf0angw',
#    'end': '0zik0zb0000020609gngbg5thf'},
#   'exposureConfig': {'reason': None, 'status': 'COMMENT_ON'},
#   'count': {'comment': 259,
#    'reply': 126,
#    'exposeCount': 246,
#    'delCommentByUser': 16,
#    'delCommentByMon': 0,
#    'blindCommentByUser': 0,
#    'blindReplyByUser': 0,
#    'total': 385},
#   'listStatus': 'all',
#   'sort': 'FAVORITE',
#   'bestList': []},
#  'date': '2023-05-03T06:31:54+0000'}

# %%
import pandas as pd

# %%
temp
# Out:
# {'success': True,
#  'code': '1000',
#  'message': '요청을 성공적으로 처리하였습니다.',
#  'lang': 'ko',
#  'country': 'KR',
#  'result': {'commentList': [{'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790684449149813072',
#     'parentCommentNo': '790684449149813072',
#     'replyLevel': 1,
#     'replyCount': 49,
#     'replyAllCount': 49,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683067076799,
#     'contents': '옛날 80~90년대는 공무원 하라고해도 하는사람 없었음.  얼마나 하는 사람이 없으면 읍,면,동장이 적합한 인재있으면 추천해줘서 공무원되고 그런 시절이 있었지... 소개팅이나 맞선 시장에서 쳐주지도 안했다더라.  어떻게보면 정상적으로 돌아가고 있는거',
#     'userIdNo': '4bfAA',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'nobl****',
#     'userProfileImage': 'https://phinf.pstatic.net/contact/20190508_58/1557304706337vcRui_JPEG/KakaoTalk_20190221_131524236.jpg',
#     'profileType': 'naver',
#     'modTime': '2023-05-03T07:37:56+0900',
#     'modTimeGmt': '2023-05-02T22:37:56+0000',
#     'regTime': '2023-05-03T07:37:56+0900',
#     'regTimeGmt': '2023-05-02T22:37:56+0000',
#     'sympathyCount': 767,
#     'antipathyCount': 101,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '4bfAA',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'nobl****',
#     'maskedUserName': 'no****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790686872937431204',
#     'parentCommentNo': '790686872937431204',
#     'replyLevel': 1,
#     'replyCount': 24,
#     'replyAllCount': 24,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683069334045,
#     'contents': '공무원을 왜 하냐\n월급도 적지 연금도 바닥이고\n\n자기 발전도\n 없구',
#     'userIdNo': '1XNEl',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'dk30****',
#     'userProfileImage': 'https://phinf.pstatic.net/contact/20160528_83/1464427382150ucCAT_PNG/avatar_profile.png',
#     'profileType': 'naver',
#     'modTime': '2023-05-03T08:15:34+0900',
#     'modTimeGmt': '2023-05-02T23:15:34+0000',
#     'regTime': '2023-05-03T08:15:34+0900',
#     'regTimeGmt': '2023-05-02T23:15:34+0000',
#     'sympathyCount': 270,
#     'antipathyCount': 25,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '1XNEl',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'dk30****',
#     'maskedUserName': 'dk****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790684392560263183',
#     'parentCommentNo': '790684392560263183',
#     'replyLevel': 1,
#     'replyCount': 11,
#     'replyAllCount': 11,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683067024557,
#     'contents': '공무원합격은 귄성0',
#     'userIdNo': '8pJj',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'see_****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T07:37:04+0900',
#     'modTimeGmt': '2023-05-02T22:37:04+0000',
#     'regTime': '2023-05-03T07:37:04+0900',
#     'regTimeGmt': '2023-05-02T22:37:04+0000',
#     'sympathyCount': 233,
#     'antipathyCount': 37,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '8pJj',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'see_****',
#     'maskedUserName': 'se****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790685293597425678',
#     'parentCommentNo': '790685293597425678',
#     'replyLevel': 1,
#     'replyCount': 5,
#     'replyAllCount': 5,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683067863000,
#     'contents': '뭘 어떻게 했길래 빚이 쌓이냐?? 그간 공시생들 돈 쪽쪽 빨았을텐데???',
#     'userIdNo': '4LZsr',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'cksg****',
#     'userProfileImage': 'https://phinf.pstatic.net/contact/20221129_295/1669714353766k9XAo_PNG/avatar_profile.png',
#     'profileType': 'naver',
#     'modTime': '2023-05-03T07:51:03+0900',
#     'modTimeGmt': '2023-05-02T22:51:03+0000',
#     'regTime': '2023-05-03T07:51:03+0900',
#     'regTimeGmt': '2023-05-02T22:51:03+0000',
#     'sympathyCount': 132,
#     'antipathyCount': 4,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '4LZsr',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'cksg****',
#     'maskedUserName': 'ck****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790688082843140214',
#     'parentCommentNo': '790688082843140214',
#     'replyLevel': 1,
#     'replyCount': 6,
#     'replyAllCount': 6,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683070461145,
#     'contents': '공무원은 하면 안된다.일이 편한것도 아니고, 잦은 부서 이동으로 10년간 신규처럼 일해야 된다. 민선제의 혼돈으로 인해 시군구청장이 재선을 위해 쓸데없는 일 엄청 만든다.그리고 각 시의원들이 보좌관 둘 수 있어서 공무원한테 자료요구 엄청나고, 스마트한 시민과 악성 민원으로 항상 시달리며 30년 해도 월 5~600  가량 이다. 누군가에겐 크지만 누군가에겐 10년차면 가져갈 금액이지. 마지막으로 남은연금도 65세 이상 돼야 받을수 있고 ,정년은 60세라서 5년간 손 빨아야됨. 연금은 국민연금',
#     'userIdNo': 'M5eX',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'jung****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T08:34:21+0900',
#     'modTimeGmt': '2023-05-02T23:34:21+0000',
#     'regTime': '2023-05-03T08:34:21+0900',
#     'regTimeGmt': '2023-05-02T23:34:21+0000',
#     'sympathyCount': 110,
#     'antipathyCount': 5,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': 'M5eX',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'jung****',
#     'maskedUserName': 'ju****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790683809988214791',
#     'parentCommentNo': '790683809988214791',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683066481262,
#     'contents': '유명강사들 다른학원 이직하는거보고 뭔가 쎄한 느낌들던데..역쉬.',
#     'userIdNo': '1Edt8',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'yws1****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T07:28:01+0900',
#     'modTimeGmt': '2023-05-02T22:28:01+0000',
#     'regTime': '2023-05-03T07:28:01+0900',
#     'regTimeGmt': '2023-05-02T22:28:01+0000',
#     'sympathyCount': 65,
#     'antipathyCount': 5,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '1Edt8',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'yws1****',
#     'maskedUserName': 'yw****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790693254185091332',
#     'parentCommentNo': '790693254185091332',
#     'replyLevel': 1,
#     'replyCount': 1,
#     'replyAllCount': 1,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683075277207,
#     'contents': '공무원보다 국회의원놈들 월급을 최저시급으로 깎아야된다.',
#     'userIdNo': '1FZpG',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'haow****',
#     'userProfileImage': 'https://phinf.pstatic.net/contact/20200320_19/1584632311924nfy4V_PNG/avatar_profile.png',
#     'profileType': 'naver',
#     'modTime': '2023-05-03T09:54:37+0900',
#     'modTimeGmt': '2023-05-03T00:54:37+0000',
#     'regTime': '2023-05-03T09:54:37+0900',
#     'regTimeGmt': '2023-05-03T00:54:37+0000',
#     'sympathyCount': 45,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '1FZpG',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'haow****',
#     'maskedUserName': 'ha****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790693657945571728',
#     'parentCommentNo': '790693657945571728',
#     'replyLevel': 1,
#     'replyCount': 1,
#     'replyAllCount': 1,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683075653824,
#     'contents': '월급 500받는 사람처럼 업무, 욕받이 시키는데 월급은 최저임금주고 남들은 몇억씩 챙겨나가는 퇴직금조차 못받고 연금은 개박살나서 국민연금이랑 별차이도 없는수준까지 내려왔는데 도대체 아무런 메리트가 없는 직업인데 할 이유가 없잖아...',
#     'userIdNo': '37fW7',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'canu****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T10:00:53+0900',
#     'modTimeGmt': '2023-05-03T01:00:53+0000',
#     'regTime': '2023-05-03T10:00:53+0900',
#     'regTimeGmt': '2023-05-03T01:00:53+0000',
#     'sympathyCount': 43,
#     'antipathyCount': 3,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '37fW7',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'canu****',
#     'maskedUserName': 'ca****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790696553558835632',
#     'parentCommentNo': '790696553558835632',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683078350131,
#     'contents': '공무원 요즘 하고 싶어 하겠냐? 그나마 바라볼 공무원연금도 반토막 났는데. 차라리 국민연금을 달라 하는 공무원들이 태반이다. 박봉이고. 그렇다고 워라벨을 챙기나? 칼퇴하는 공무원은 일부고, 일에 시달려서 늦게 퇴근한다. 인수인계도 잘 안 되고, 전 근무자가 다음 근무자 죽어보라고 컴퓨터 가져가는 경우도 있다. 거기다 철밥통이라고 윗사람도 안 잘리는데 그 사람이 진상이면, 그냥 계속 봐야 한다. 거기다 군대마냥 상하관계 심하고. 그러니 공무원 시험 힘들게 하고 몇 달 다니다 나가거나, 버티다 힘들어서 자살하는 경우가 많다. 짠하다.',
#     'userIdNo': '12A0r',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'kse5****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T10:45:50+0900',
#     'modTimeGmt': '2023-05-03T01:45:50+0000',
#     'regTime': '2023-05-03T10:45:50+0900',
#     'regTimeGmt': '2023-05-03T01:45:50+0000',
#     'sympathyCount': 41,
#     'antipathyCount': 3,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '12A0r',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'kse5****',
#     'maskedUserName': 'ks****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790685561244352572',
#     'parentCommentNo': '790685561244352572',
#     'replyLevel': 1,
#     'replyCount': 2,
#     'replyAllCount': 2,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683068112817,
#     'contents': '문재인 정권때 공무원 수 엄청 늘리더니 결국 이꼴 남',
#     'userIdNo': '2CQ6r',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'dead****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T07:55:12+0900',
#     'modTimeGmt': '2023-05-02T22:55:12+0000',
#     'regTime': '2023-05-03T07:55:12+0900',
#     'regTimeGmt': '2023-05-02T22:55:12+0000',
#     'sympathyCount': 42,
#     'antipathyCount': 12,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '2CQ6r',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'dead****',
#     'maskedUserName': 'de****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790694785743585474',
#     'parentCommentNo': '790694785743585474',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683076703098,
#     'contents': '어차피 별볼일 없는 허수들만 빠진거고 경쟁은 여전히 치열함ㅋㅋ',
#     'userIdNo': '2rv8y',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'qed1****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T10:18:23+0900',
#     'modTimeGmt': '2023-05-03T01:18:23+0000',
#     'regTime': '2023-05-03T10:18:23+0900',
#     'regTimeGmt': '2023-05-03T01:18:23+0000',
#     'sympathyCount': 28,
#     'antipathyCount': 2,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '2rv8y',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'qed1****',
#     'maskedUserName': 'qe****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790685632715292758',
#     'parentCommentNo': '790685632715292758',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683068179986,
#     'contents': '매출에 비해 마케팅 과하게하는 특히 유명연예인에 의존하는 기업과 제품은 걸러야한다. 연예인, 인플루언서, 방송ppl에 놀아나지마라.',
#     'userIdNo': '5O30A',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'youn****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T07:56:19+0900',
#     'modTimeGmt': '2023-05-02T22:56:19+0000',
#     'regTime': '2023-05-03T07:56:19+0900',
#     'regTimeGmt': '2023-05-02T22:56:19+0000',
#     'sympathyCount': 24,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '5O30A',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'youn****',
#     'maskedUserName': 'yo****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790695149322633240',
#     'parentCommentNo': '790695149322633240',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683077042908,
#     'contents': '그래도 공무원이 젤 속편함..',
#     'userIdNo': '1ZrST',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'hyun****',
#     'userProfileImage': 'https://phinf.pstatic.net/contact/20170606_164/1496753719250QInXw_PNG/avatar_profile.png',
#     'profileType': 'naver',
#     'modTime': '2023-05-03T10:24:02+0900',
#     'modTimeGmt': '2023-05-03T01:24:02+0000',
#     'regTime': '2023-05-03T10:24:02+0900',
#     'regTimeGmt': '2023-05-03T01:24:02+0000',
#     'sympathyCount': 21,
#     'antipathyCount': 3,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '1ZrST',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'hyun****',
#     'maskedUserName': 'hy****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790687737182159171',
#     'parentCommentNo': '790687737182159171',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683070139118,
#     'contents': '내실없이 너무 사업을 무리해서 확장해나가니 이런 사단이 벌어진 거임. 딱 공인중개사와 주택관리사만 하고 다른 것은 손대지 말았어야 함. 다른 자격증이나 공무원 합격자들 대부분 에듀윌로는 공부 잘 안함.',
#     'userIdNo': '1WIjZ',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'star****',
#     'userProfileImage': 'https://phinf.pstatic.net/contact/20190602_189/1559480101926ieUt7_PNG/avatar_profile.png',
#     'profileType': 'naver',
#     'modTime': '2023-05-03T08:28:59+0900',
#     'modTimeGmt': '2023-05-02T23:28:59+0000',
#     'regTime': '2023-05-03T08:28:59+0900',
#     'regTimeGmt': '2023-05-02T23:28:59+0000',
#     'sympathyCount': 18,
#     'antipathyCount': 0,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '1WIjZ',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'star****',
#     'maskedUserName': 'st****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790689260536594674',
#     'parentCommentNo': '790689260536594674',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683071557444,
#     'contents': '공기업  일반회사보다  일은힘들고  월급은  적게주니  점점인기가  없어진다  그보상으로  퇴직후  연금을  받는건데  그것도  깍으라고  난리고  점점\n의욕이  없어 질수 밖에없다',
#     'userIdNo': '6loGF',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'shbb****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T08:52:37+0900',
#     'modTimeGmt': '2023-05-02T23:52:37+0000',
#     'regTime': '2023-05-03T08:52:37+0900',
#     'regTimeGmt': '2023-05-02T23:52:37+0000',
#     'sympathyCount': 19,
#     'antipathyCount': 2,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '6loGF',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'shbb****',
#     'maskedUserName': 'sh****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790701884317892886',
#     'parentCommentNo': '790701884317892886',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683083314267,
#     'contents': '공무원이지만 진짜 할 게 아닙니다. 박봉에 책임은 엄청많고 얼마나 제약이 많은지요.',
#     'userIdNo': '2JZNu',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'blue****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T12:08:34+0900',
#     'modTimeGmt': '2023-05-03T03:08:34+0000',
#     'regTime': '2023-05-03T12:08:34+0900',
#     'regTimeGmt': '2023-05-03T03:08:34+0000',
#     'sympathyCount': 18,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '2JZNu',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'blue****',
#     'maskedUserName': 'bl****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790696063093702767',
#     'parentCommentNo': '790696063093702767',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683077893003,
#     'contents': '공무원이라는 직업 그렇게 좋은 직업이 아니다. 첫번째 늘 야근을 하지만 초과근무 수당을 정당하게 받지 못한다. 일반공무원 경우 일일 4시간 적용되기 때문에 휴일날 초과근무을 4시간이상 하여도 동일하게 4시간만 인정되고 지급받는다. 두번째 공무원 연금은 각 개인 급여 9.8% 그리고 각 소득세, 건강보험 등 공제된다. 그럼 실수령액은 얼마 일 것 같습니까?.  공무원 연금 이제 국민연금 수준으로 노후대책이 되지 않는다. 모두다 옛말이다.',
#     'userIdNo': 'UpQC',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'haha****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T10:38:13+0900',
#     'modTimeGmt': '2023-05-03T01:38:13+0000',
#     'regTime': '2023-05-03T10:38:13+0900',
#     'regTimeGmt': '2023-05-03T01:38:13+0000',
#     'sympathyCount': 17,
#     'antipathyCount': 4,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': 'UpQC',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'haha****',
#     'maskedUserName': 'ha****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790698385060397177',
#     'parentCommentNo': '790698385060397177',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683080055975,
#     'contents': '편의점 야간 알바가 훨씬 많이 버는데 누가 공무원을 함ㅋㅋ',
#     'userIdNo': '37pRP',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'sunn****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T11:14:15+0900',
#     'modTimeGmt': '2023-05-03T02:14:15+0000',
#     'regTime': '2023-05-03T11:14:15+0900',
#     'regTimeGmt': '2023-05-03T02:14:15+0000',
#     'sympathyCount': 15,
#     'antipathyCount': 3,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '37pRP',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'sunn****',
#     'maskedUserName': 'su****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790696844240879786',
#     'parentCommentNo': '790696844240879786',
#     'replyLevel': 1,
#     'replyCount': 1,
#     'replyAllCount': 1,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683078620516,
#     'contents': '1000명에게 물어 봤더니....중소기업 갈래...공무원 할래...질문 했습니다...결과는 중소기업 17.5%  공무원 78.4 %  기타 4.1%  로 나왔습니다  ..그래도 공무원을 선택합니다',
#     'userIdNo': 'd8Vef',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'hswo****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T10:50:20+0900',
#     'modTimeGmt': '2023-05-03T01:50:20+0000',
#     'regTime': '2023-05-03T10:50:20+0900',
#     'regTimeGmt': '2023-05-03T01:50:20+0000',
#     'sympathyCount': 12,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': 'd8Vef',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'hswo****',
#     'maskedUserName': 'hs****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790689526187032833',
#     'parentCommentNo': '790689526187032833',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683071805169,
#     'contents': '권성동 한테 원생 다 뺐겨서 망한듯',
#     'userIdNo': '4ICUL',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': '7796****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T08:56:45+0900',
#     'modTimeGmt': '2023-05-02T23:56:45+0000',
#     'regTime': '2023-05-03T08:56:45+0900',
#     'regTimeGmt': '2023-05-02T23:56:45+0000',
#     'sympathyCount': 15,
#     'antipathyCount': 5,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '4ICUL',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': '7796****',
#     'maskedUserName': '77****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790690811640545547',
#     'parentCommentNo': '790690811640545547',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683073002769,
#     'contents': '공무원하면 먹고살기 힘들어요',
#     'userIdNo': '2Pp6f',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 't100****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T09:16:42+0900',
#     'modTimeGmt': '2023-05-03T00:16:42+0000',
#     'regTime': '2023-05-03T09:16:42+0900',
#     'regTimeGmt': '2023-05-03T00:16:42+0000',
#     'sympathyCount': 10,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
# ...
#     'idProvider': 'naver',
#     'userName': 'dana****',
#     'userProfileImage': 'https://phinf.pstatic.net/contact/2/2011/9/9/danamu93_1315579529238.png',
#     'profileType': 'naver',
#     'modTime': '2023-05-03T10:14:45+0900',
#     'modTimeGmt': '2023-05-03T01:14:45+0000',
#     'regTime': '2023-05-03T10:14:45+0900',
#     'regTimeGmt': '2023-05-03T01:14:45+0000',
#     'sympathyCount': 4,
#     'antipathyCount': 4,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': 'KG6M',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'dana****',
#     'maskedUserName': 'da****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790692598934143152',
#     'parentCommentNo': '790692598934143152',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683074666734,
#     'contents': '고3 학생이 한때 100만명이었다가, 지금은 30만명.  앞으로 10만명이 얼마 안남았다.  출생율 0.7명의 한국여자가 그저 한심하고 대단하다',
#     'userIdNo': 'Iih1',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'pali****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T09:44:26+0900',
#     'modTimeGmt': '2023-05-03T00:44:26+0000',
#     'regTime': '2023-05-03T09:44:26+0900',
#     'regTimeGmt': '2023-05-03T00:44:26+0000',
#     'sympathyCount': 3,
#     'antipathyCount': 3,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': 'Iih1',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'pali****',
#     'maskedUserName': 'pa****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790710002863046957',
#     'parentCommentNo': '790710002863046957',
#     'replyLevel': 1,
#     'replyCount': 2,
#     'replyAllCount': 2,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683090875901,
#     'contents': '진짜 인생실패한 사람들이나 공무원 준비하더라 요새',
#     'userIdNo': '2RmDw',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'wjdt****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T14:14:35+0900',
#     'modTimeGmt': '2023-05-03T05:14:35+0000',
#     'regTime': '2023-05-03T14:14:35+0900',
#     'regTimeGmt': '2023-05-03T05:14:35+0000',
#     'sympathyCount': 2,
#     'antipathyCount': 2,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '2RmDw',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'wjdt****',
#     'maskedUserName': 'wj****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790690313323675988',
#     'parentCommentNo': '790690313323675988',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683072538948,
#     'contents': '9급 공무원은 할 사람만 하자~~ 고급인력들이 동사무소서 등본이나 발급하고 있다는건 국가적으로 손해다~',
#     'userIdNo': '2LJHa',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'mira****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T09:08:58+0900',
#     'modTimeGmt': '2023-05-03T00:08:58+0000',
#     'regTime': '2023-05-03T09:08:58+0900',
#     'regTimeGmt': '2023-05-03T00:08:58+0000',
#     'sympathyCount': 2,
#     'antipathyCount': 2,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '2LJHa',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'mira****',
#     'maskedUserName': 'mi****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'default_economy',
#     'commentNo': '790712623984279717',
#     'parentCommentNo': '790712623984279717',
#     'replyLevel': 1,
#     'replyCount': 1,
#     'replyAllCount': 1,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683093316890,
#     'contents': '왜 항상 가만히 있는 공무원만 머리채 잡고 닌리들이냐…ㅋㅋㅋ 부러워서 그러는 거임? 그게 아니면 도대체 왜? 남의 직업 까내리면서 본인이 더 우월하다고 느낀다면 참 불쌍한 인생들이다 얼마나 자존감이 없으면',
#     'userIdNo': '1B8ba',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'sk98****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T14:55:16+0900',
#     'modTimeGmt': '2023-05-03T05:55:16+0000',
#     'regTime': '2023-05-03T14:55:16+0900',
#     'regTimeGmt': '2023-05-03T05:55:16+0000',
#     'sympathyCount': 1,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '1B8ba',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'sk98****',
#     'maskedUserName': 'sk****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790708019578011979',
#     'parentCommentNo': '790708019578011979',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683089028258,
#     'contents': '9급공채 공무원은 그냥 중졸,고졸 기타 사회취약계층들만 할수 있게 못박아야 한다고 봄. 전문대,4년제대 졸업한 사람들이 하는건 너무 인력낭비라 생각함.',
#     'userIdNo': 'bGVpW',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'last****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T13:43:48+0900',
#     'modTimeGmt': '2023-05-03T04:43:48+0000',
#     'regTime': '2023-05-03T13:43:48+0900',
#     'regTimeGmt': '2023-05-03T04:43:48+0000',
#     'sympathyCount': 1,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': False,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': 'bGVpW',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'last****',
#     'maskedUserName': 'la****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False},
#    {'ticket': 'news',
#     'objectId': 'news018,0005477530',
#     'categoryId': '*',
#     'templateId': 'view_economy',
#     'commentNo': '790705234895700220',
#     'parentCommentNo': '790705234895700220',
#     'replyLevel': 1,
#     'replyCount': 0,
#     'replyAllCount': 0,
#     'replyPreviewNo': None,
#     'replyList': None,
#     'imageCount': 0,
#     'imageList': None,
#     'imagePathList': None,
#     'imageWidthList': None,
#     'imageHeightList': None,
#     'commentType': 'txt',
#     'stickerId': None,
#     'sticker': None,
#     'sortValue': 1683086435694,
#     'contents': '성동이형이 있는데 에듀윌 따위가 뭐라고 감히…',
#     'userIdNo': '34NGY',
#     'exposedUserIp': None,
#     'lang': 'ko',
#     'country': 'KR',
#     'idType': 'naver',
#     'idProvider': 'naver',
#     'userName': 'simo****',
#     'userProfileImage': None,
#     'profileType': 'naver',
#     'modTime': '2023-05-03T13:00:35+0900',
#     'modTimeGmt': '2023-05-03T04:00:35+0000',
#     'regTime': '2023-05-03T13:00:35+0900',
#     'regTimeGmt': '2023-05-03T04:00:35+0000',
#     'sympathyCount': 1,
#     'antipathyCount': 1,
#     'hideReplyButton': False,
#     'status': 0,
#     'mine': False,
#     'best': False,
#     'mentions': None,
#     'toUser': None,
#     'userStatus': 0,
#     'categoryImage': None,
#     'open': True,
#     'levelCode': None,
#     'grades': None,
#     'sympathy': False,
#     'antipathy': False,
#     'metaInfo': None,
#     'extension': None,
#     'translation': None,
#     'report': None,
#     'middleBlindReport': False,
#     'spamInfo': None,
#     'userHomepageUrl': None,
#     'defamation': False,
#     'hiddenByCleanbot': False,
#     'score': 0.0,
#     'ratings': None,
#     'following': False,
#     'managerLike': False,
#     'pick': False,
#     'attachmentList': [],
#     'reference': None,
#     'inspectionId': None,
#     'visible': True,
#     'userBlocked': False,
#     'idNo': '34NGY',
#     'manager': False,
#     'deleted': False,
#     'blindReport': False,
#     'expose': True,
#     'serviceId': None,
#     'maskedUserId': 'simo****',
#     'maskedUserName': 'si****',
#     'blind': False,
#     'secret': False,
#     'profileUserId': None,
#     'exposeByCountry': True,
#     'validateBanWords': False,
#     'containText': True,
#     'virtual': False,
#     'originalStatus': 0,
#     'anonymous': False}],
#   'pageModel': {'page': 1,
#    'pageSize': 100,
#    'indexSize': 10,
#    'startRow': 1,
#    'endRow': 100,
#    'totalRows': 259,
#    'startIndex': 0,
#    'totalPages': 3,
#    'firstPage': 1,
#    'prevPage': 0,
#    'nextPage': 2,
#    'lastPage': 3,
#    'current': None,
#    'threshold': None,
#    'moveToLastPage': False,
#    'moveToComment': False,
#    'moveToLastPrev': False},
#   'morePage': {'prev': '10000o90000op06guicil48ars',
#    'next': '10000000000010609lm298q3ng',
#    'start': '10000ii0000lb0609e8tf0angw',
#    'end': '0zik0zb0000020609gngbg5thf'},
#   'exposureConfig': {'reason': None, 'status': 'COMMENT_ON'},
#   'count': {'comment': 259,
#    'reply': 126,
#    'exposeCount': 246,
#    'delCommentByUser': 16,
#    'delCommentByMon': 0,
#    'blindCommentByUser': 0,
#    'blindReplyByUser': 0,
#    'total': 385},
#   'listStatus': 'all',
#   'sort': 'FAVORITE',
#   'bestList': []},
#  'date': '2023-05-03T06:31:54+0000'}

# %%
total_comment = []
try : 
    comment = list(pd.DataFrame(temp['result']['commentList'])['contents'])
    for j in range(len(comment)):
        total_comment.append(comment[j])
    if len(comment)<97: 
        pass 
    else: 
        i+=1
except :
    pass

# %%
temp['result']
# Out:
# {'commentList': [{'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790684449149813072',
#    'parentCommentNo': '790684449149813072',
#    'replyLevel': 1,
#    'replyCount': 49,
#    'replyAllCount': 49,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683067076799,
#    'contents': '옛날 80~90년대는 공무원 하라고해도 하는사람 없었음.  얼마나 하는 사람이 없으면 읍,면,동장이 적합한 인재있으면 추천해줘서 공무원되고 그런 시절이 있었지... 소개팅이나 맞선 시장에서 쳐주지도 안했다더라.  어떻게보면 정상적으로 돌아가고 있는거',
#    'userIdNo': '4bfAA',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'nobl****',
#    'userProfileImage': 'https://phinf.pstatic.net/contact/20190508_58/1557304706337vcRui_JPEG/KakaoTalk_20190221_131524236.jpg',
#    'profileType': 'naver',
#    'modTime': '2023-05-03T07:37:56+0900',
#    'modTimeGmt': '2023-05-02T22:37:56+0000',
#    'regTime': '2023-05-03T07:37:56+0900',
#    'regTimeGmt': '2023-05-02T22:37:56+0000',
#    'sympathyCount': 767,
#    'antipathyCount': 101,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '4bfAA',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'nobl****',
#    'maskedUserName': 'no****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'default_economy',
#    'commentNo': '790686872937431204',
#    'parentCommentNo': '790686872937431204',
#    'replyLevel': 1,
#    'replyCount': 24,
#    'replyAllCount': 24,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683069334045,
#    'contents': '공무원을 왜 하냐\n월급도 적지 연금도 바닥이고\n\n자기 발전도\n 없구',
#    'userIdNo': '1XNEl',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'dk30****',
#    'userProfileImage': 'https://phinf.pstatic.net/contact/20160528_83/1464427382150ucCAT_PNG/avatar_profile.png',
#    'profileType': 'naver',
#    'modTime': '2023-05-03T08:15:34+0900',
#    'modTimeGmt': '2023-05-02T23:15:34+0000',
#    'regTime': '2023-05-03T08:15:34+0900',
#    'regTimeGmt': '2023-05-02T23:15:34+0000',
#    'sympathyCount': 270,
#    'antipathyCount': 25,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '1XNEl',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'dk30****',
#    'maskedUserName': 'dk****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'default_economy',
#    'commentNo': '790684392560263183',
#    'parentCommentNo': '790684392560263183',
#    'replyLevel': 1,
#    'replyCount': 11,
#    'replyAllCount': 11,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683067024557,
#    'contents': '공무원합격은 귄성0',
#    'userIdNo': '8pJj',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'see_****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T07:37:04+0900',
#    'modTimeGmt': '2023-05-02T22:37:04+0000',
#    'regTime': '2023-05-03T07:37:04+0900',
#    'regTimeGmt': '2023-05-02T22:37:04+0000',
#    'sympathyCount': 233,
#    'antipathyCount': 37,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': True,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '8pJj',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'see_****',
#    'maskedUserName': 'se****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'default_economy',
#    'commentNo': '790685293597425678',
#    'parentCommentNo': '790685293597425678',
#    'replyLevel': 1,
#    'replyCount': 5,
#    'replyAllCount': 5,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683067863000,
#    'contents': '뭘 어떻게 했길래 빚이 쌓이냐?? 그간 공시생들 돈 쪽쪽 빨았을텐데???',
#    'userIdNo': '4LZsr',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'cksg****',
#    'userProfileImage': 'https://phinf.pstatic.net/contact/20221129_295/1669714353766k9XAo_PNG/avatar_profile.png',
#    'profileType': 'naver',
#    'modTime': '2023-05-03T07:51:03+0900',
#    'modTimeGmt': '2023-05-02T22:51:03+0000',
#    'regTime': '2023-05-03T07:51:03+0900',
#    'regTimeGmt': '2023-05-02T22:51:03+0000',
#    'sympathyCount': 132,
#    'antipathyCount': 4,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '4LZsr',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'cksg****',
#    'maskedUserName': 'ck****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790688082843140214',
#    'parentCommentNo': '790688082843140214',
#    'replyLevel': 1,
#    'replyCount': 6,
#    'replyAllCount': 6,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683070461145,
#    'contents': '공무원은 하면 안된다.일이 편한것도 아니고, 잦은 부서 이동으로 10년간 신규처럼 일해야 된다. 민선제의 혼돈으로 인해 시군구청장이 재선을 위해 쓸데없는 일 엄청 만든다.그리고 각 시의원들이 보좌관 둘 수 있어서 공무원한테 자료요구 엄청나고, 스마트한 시민과 악성 민원으로 항상 시달리며 30년 해도 월 5~600  가량 이다. 누군가에겐 크지만 누군가에겐 10년차면 가져갈 금액이지. 마지막으로 남은연금도 65세 이상 돼야 받을수 있고 ,정년은 60세라서 5년간 손 빨아야됨. 연금은 국민연금',
#    'userIdNo': 'M5eX',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'jung****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T08:34:21+0900',
#    'modTimeGmt': '2023-05-02T23:34:21+0000',
#    'regTime': '2023-05-03T08:34:21+0900',
#    'regTimeGmt': '2023-05-02T23:34:21+0000',
#    'sympathyCount': 110,
#    'antipathyCount': 5,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': True,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': 'M5eX',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'jung****',
#    'maskedUserName': 'ju****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790683809988214791',
#    'parentCommentNo': '790683809988214791',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683066481262,
#    'contents': '유명강사들 다른학원 이직하는거보고 뭔가 쎄한 느낌들던데..역쉬.',
#    'userIdNo': '1Edt8',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'yws1****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T07:28:01+0900',
#    'modTimeGmt': '2023-05-02T22:28:01+0000',
#    'regTime': '2023-05-03T07:28:01+0900',
#    'regTimeGmt': '2023-05-02T22:28:01+0000',
#    'sympathyCount': 65,
#    'antipathyCount': 5,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': True,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '1Edt8',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'yws1****',
#    'maskedUserName': 'yw****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'default_economy',
#    'commentNo': '790693254185091332',
#    'parentCommentNo': '790693254185091332',
#    'replyLevel': 1,
#    'replyCount': 1,
#    'replyAllCount': 1,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683075277207,
#    'contents': '공무원보다 국회의원놈들 월급을 최저시급으로 깎아야된다.',
#    'userIdNo': '1FZpG',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'haow****',
#    'userProfileImage': 'https://phinf.pstatic.net/contact/20200320_19/1584632311924nfy4V_PNG/avatar_profile.png',
#    'profileType': 'naver',
#    'modTime': '2023-05-03T09:54:37+0900',
#    'modTimeGmt': '2023-05-03T00:54:37+0000',
#    'regTime': '2023-05-03T09:54:37+0900',
#    'regTimeGmt': '2023-05-03T00:54:37+0000',
#    'sympathyCount': 45,
#    'antipathyCount': 1,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '1FZpG',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'haow****',
#    'maskedUserName': 'ha****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790693657945571728',
#    'parentCommentNo': '790693657945571728',
#    'replyLevel': 1,
#    'replyCount': 1,
#    'replyAllCount': 1,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683075653824,
#    'contents': '월급 500받는 사람처럼 업무, 욕받이 시키는데 월급은 최저임금주고 남들은 몇억씩 챙겨나가는 퇴직금조차 못받고 연금은 개박살나서 국민연금이랑 별차이도 없는수준까지 내려왔는데 도대체 아무런 메리트가 없는 직업인데 할 이유가 없잖아...',
#    'userIdNo': '37fW7',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'canu****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T10:00:53+0900',
#    'modTimeGmt': '2023-05-03T01:00:53+0000',
#    'regTime': '2023-05-03T10:00:53+0900',
#    'regTimeGmt': '2023-05-03T01:00:53+0000',
#    'sympathyCount': 43,
#    'antipathyCount': 3,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '37fW7',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'canu****',
#    'maskedUserName': 'ca****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790696553558835632',
#    'parentCommentNo': '790696553558835632',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683078350131,
#    'contents': '공무원 요즘 하고 싶어 하겠냐? 그나마 바라볼 공무원연금도 반토막 났는데. 차라리 국민연금을 달라 하는 공무원들이 태반이다. 박봉이고. 그렇다고 워라벨을 챙기나? 칼퇴하는 공무원은 일부고, 일에 시달려서 늦게 퇴근한다. 인수인계도 잘 안 되고, 전 근무자가 다음 근무자 죽어보라고 컴퓨터 가져가는 경우도 있다. 거기다 철밥통이라고 윗사람도 안 잘리는데 그 사람이 진상이면, 그냥 계속 봐야 한다. 거기다 군대마냥 상하관계 심하고. 그러니 공무원 시험 힘들게 하고 몇 달 다니다 나가거나, 버티다 힘들어서 자살하는 경우가 많다. 짠하다.',
#    'userIdNo': '12A0r',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'kse5****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T10:45:50+0900',
#    'modTimeGmt': '2023-05-03T01:45:50+0000',
#    'regTime': '2023-05-03T10:45:50+0900',
#    'regTimeGmt': '2023-05-03T01:45:50+0000',
#    'sympathyCount': 41,
#    'antipathyCount': 3,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '12A0r',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'kse5****',
#    'maskedUserName': 'ks****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790685561244352572',
#    'parentCommentNo': '790685561244352572',
#    'replyLevel': 1,
#    'replyCount': 2,
#    'replyAllCount': 2,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683068112817,
#    'contents': '문재인 정권때 공무원 수 엄청 늘리더니 결국 이꼴 남',
#    'userIdNo': '2CQ6r',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'dead****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T07:55:12+0900',
#    'modTimeGmt': '2023-05-02T22:55:12+0000',
#    'regTime': '2023-05-03T07:55:12+0900',
#    'regTimeGmt': '2023-05-02T22:55:12+0000',
#    'sympathyCount': 42,
#    'antipathyCount': 12,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '2CQ6r',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'dead****',
#    'maskedUserName': 'de****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'default_economy',
#    'commentNo': '790694785743585474',
#    'parentCommentNo': '790694785743585474',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683076703098,
#    'contents': '어차피 별볼일 없는 허수들만 빠진거고 경쟁은 여전히 치열함ㅋㅋ',
#    'userIdNo': '2rv8y',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'qed1****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T10:18:23+0900',
#    'modTimeGmt': '2023-05-03T01:18:23+0000',
#    'regTime': '2023-05-03T10:18:23+0900',
#    'regTimeGmt': '2023-05-03T01:18:23+0000',
#    'sympathyCount': 28,
#    'antipathyCount': 2,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': True,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '2rv8y',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'qed1****',
#    'maskedUserName': 'qe****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790685632715292758',
#    'parentCommentNo': '790685632715292758',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683068179986,
#    'contents': '매출에 비해 마케팅 과하게하는 특히 유명연예인에 의존하는 기업과 제품은 걸러야한다. 연예인, 인플루언서, 방송ppl에 놀아나지마라.',
#    'userIdNo': '5O30A',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'youn****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T07:56:19+0900',
#    'modTimeGmt': '2023-05-02T22:56:19+0000',
#    'regTime': '2023-05-03T07:56:19+0900',
#    'regTimeGmt': '2023-05-02T22:56:19+0000',
#    'sympathyCount': 24,
#    'antipathyCount': 1,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '5O30A',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'youn****',
#    'maskedUserName': 'yo****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790695149322633240',
#    'parentCommentNo': '790695149322633240',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683077042908,
#    'contents': '그래도 공무원이 젤 속편함..',
#    'userIdNo': '1ZrST',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'hyun****',
#    'userProfileImage': 'https://phinf.pstatic.net/contact/20170606_164/1496753719250QInXw_PNG/avatar_profile.png',
#    'profileType': 'naver',
#    'modTime': '2023-05-03T10:24:02+0900',
#    'modTimeGmt': '2023-05-03T01:24:02+0000',
#    'regTime': '2023-05-03T10:24:02+0900',
#    'regTimeGmt': '2023-05-03T01:24:02+0000',
#    'sympathyCount': 21,
#    'antipathyCount': 3,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '1ZrST',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'hyun****',
#    'maskedUserName': 'hy****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'default_economy',
#    'commentNo': '790687737182159171',
#    'parentCommentNo': '790687737182159171',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683070139118,
#    'contents': '내실없이 너무 사업을 무리해서 확장해나가니 이런 사단이 벌어진 거임. 딱 공인중개사와 주택관리사만 하고 다른 것은 손대지 말았어야 함. 다른 자격증이나 공무원 합격자들 대부분 에듀윌로는 공부 잘 안함.',
#    'userIdNo': '1WIjZ',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'star****',
#    'userProfileImage': 'https://phinf.pstatic.net/contact/20190602_189/1559480101926ieUt7_PNG/avatar_profile.png',
#    'profileType': 'naver',
#    'modTime': '2023-05-03T08:28:59+0900',
#    'modTimeGmt': '2023-05-02T23:28:59+0000',
#    'regTime': '2023-05-03T08:28:59+0900',
#    'regTimeGmt': '2023-05-02T23:28:59+0000',
#    'sympathyCount': 18,
#    'antipathyCount': 0,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '1WIjZ',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'star****',
#    'maskedUserName': 'st****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'default_economy',
#    'commentNo': '790689260536594674',
#    'parentCommentNo': '790689260536594674',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683071557444,
#    'contents': '공기업  일반회사보다  일은힘들고  월급은  적게주니  점점인기가  없어진다  그보상으로  퇴직후  연금을  받는건데  그것도  깍으라고  난리고  점점\n의욕이  없어 질수 밖에없다',
#    'userIdNo': '6loGF',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'shbb****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T08:52:37+0900',
#    'modTimeGmt': '2023-05-02T23:52:37+0000',
#    'regTime': '2023-05-03T08:52:37+0900',
#    'regTimeGmt': '2023-05-02T23:52:37+0000',
#    'sympathyCount': 19,
#    'antipathyCount': 2,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': True,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '6loGF',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'shbb****',
#    'maskedUserName': 'sh****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'default_economy',
#    'commentNo': '790701884317892886',
#    'parentCommentNo': '790701884317892886',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683083314267,
#    'contents': '공무원이지만 진짜 할 게 아닙니다. 박봉에 책임은 엄청많고 얼마나 제약이 많은지요.',
#    'userIdNo': '2JZNu',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'blue****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T12:08:34+0900',
#    'modTimeGmt': '2023-05-03T03:08:34+0000',
#    'regTime': '2023-05-03T12:08:34+0900',
#    'regTimeGmt': '2023-05-03T03:08:34+0000',
#    'sympathyCount': 18,
#    'antipathyCount': 1,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '2JZNu',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'blue****',
#    'maskedUserName': 'bl****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790696063093702767',
#    'parentCommentNo': '790696063093702767',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683077893003,
#    'contents': '공무원이라는 직업 그렇게 좋은 직업이 아니다. 첫번째 늘 야근을 하지만 초과근무 수당을 정당하게 받지 못한다. 일반공무원 경우 일일 4시간 적용되기 때문에 휴일날 초과근무을 4시간이상 하여도 동일하게 4시간만 인정되고 지급받는다. 두번째 공무원 연금은 각 개인 급여 9.8% 그리고 각 소득세, 건강보험 등 공제된다. 그럼 실수령액은 얼마 일 것 같습니까?.  공무원 연금 이제 국민연금 수준으로 노후대책이 되지 않는다. 모두다 옛말이다.',
#    'userIdNo': 'UpQC',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'haha****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T10:38:13+0900',
#    'modTimeGmt': '2023-05-03T01:38:13+0000',
#    'regTime': '2023-05-03T10:38:13+0900',
#    'regTimeGmt': '2023-05-03T01:38:13+0000',
#    'sympathyCount': 17,
#    'antipathyCount': 4,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': True,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': 'UpQC',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'haha****',
#    'maskedUserName': 'ha****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790698385060397177',
#    'parentCommentNo': '790698385060397177',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683080055975,
#    'contents': '편의점 야간 알바가 훨씬 많이 버는데 누가 공무원을 함ㅋㅋ',
#    'userIdNo': '37pRP',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'sunn****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T11:14:15+0900',
#    'modTimeGmt': '2023-05-03T02:14:15+0000',
#    'regTime': '2023-05-03T11:14:15+0900',
#    'regTimeGmt': '2023-05-03T02:14:15+0000',
#    'sympathyCount': 15,
#    'antipathyCount': 3,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '37pRP',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'sunn****',
#    'maskedUserName': 'su****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'default_economy',
#    'commentNo': '790696844240879786',
#    'parentCommentNo': '790696844240879786',
#    'replyLevel': 1,
#    'replyCount': 1,
#    'replyAllCount': 1,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683078620516,
#    'contents': '1000명에게 물어 봤더니....중소기업 갈래...공무원 할래...질문 했습니다...결과는 중소기업 17.5%  공무원 78.4 %  기타 4.1%  로 나왔습니다  ..그래도 공무원을 선택합니다',
#    'userIdNo': 'd8Vef',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'hswo****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T10:50:20+0900',
#    'modTimeGmt': '2023-05-03T01:50:20+0000',
#    'regTime': '2023-05-03T10:50:20+0900',
#    'regTimeGmt': '2023-05-03T01:50:20+0000',
#    'sympathyCount': 12,
#    'antipathyCount': 1,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': True,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': 'd8Vef',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'hswo****',
#    'maskedUserName': 'hs****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790689526187032833',
#    'parentCommentNo': '790689526187032833',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683071805169,
#    'contents': '권성동 한테 원생 다 뺐겨서 망한듯',
#    'userIdNo': '4ICUL',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': '7796****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T08:56:45+0900',
#    'modTimeGmt': '2023-05-02T23:56:45+0000',
#    'regTime': '2023-05-03T08:56:45+0900',
#    'regTimeGmt': '2023-05-02T23:56:45+0000',
#    'sympathyCount': 15,
#    'antipathyCount': 5,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '4ICUL',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': '7796****',
#    'maskedUserName': '77****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'default_economy',
#    'commentNo': '790690811640545547',
#    'parentCommentNo': '790690811640545547',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683073002769,
#    'contents': '공무원하면 먹고살기 힘들어요',
#    'userIdNo': '2Pp6f',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 't100****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T09:16:42+0900',
#    'modTimeGmt': '2023-05-03T00:16:42+0000',
#    'regTime': '2023-05-03T09:16:42+0900',
#    'regTimeGmt': '2023-05-03T00:16:42+0000',
#    'sympathyCount': 10,
#    'antipathyCount': 1,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': True,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '2Pp6f',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 't100****',
#    'maskedUserName': 't1****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790697352338866288',
#    'parentCommentNo': '790697352338866288',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683079093990,
#    'contents': '권성0한테 부탁하면 다 되는데 뭐하러 에듀윌 다니겠어~~',
#    'userIdNo': '4hrnU',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'shga****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T10:58:13+0900',
#    'modTimeGmt': '2023-05-03T01:58:13+0000',
#    'regTime': '2023-05-03T10:58:13+0900',
#    'regTimeGmt': '2023-05-03T01:58:13+0000',
#    'sympathyCount': 9,
#    'antipathyCount': 0,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
# ...
#    'templateId': 'default_economy',
#    'commentNo': '790694551181328753',
#    'parentCommentNo': '790694551181328753',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683076485439,
#    'contents': '재앙이가 공무원 역대급으로 뽑을땐 우리제인이 잘한다했겠지 좌파들의 단세포는 사회여러분야에서 망조로 드러나고 있다',
#    'userIdNo': 'KG6M',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'dana****',
#    'userProfileImage': 'https://phinf.pstatic.net/contact/2/2011/9/9/danamu93_1315579529238.png',
#    'profileType': 'naver',
#    'modTime': '2023-05-03T10:14:45+0900',
#    'modTimeGmt': '2023-05-03T01:14:45+0000',
#    'regTime': '2023-05-03T10:14:45+0900',
#    'regTimeGmt': '2023-05-03T01:14:45+0000',
#    'sympathyCount': 4,
#    'antipathyCount': 4,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': 'KG6M',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'dana****',
#    'maskedUserName': 'da****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790692598934143152',
#    'parentCommentNo': '790692598934143152',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683074666734,
#    'contents': '고3 학생이 한때 100만명이었다가, 지금은 30만명.  앞으로 10만명이 얼마 안남았다.  출생율 0.7명의 한국여자가 그저 한심하고 대단하다',
#    'userIdNo': 'Iih1',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'pali****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T09:44:26+0900',
#    'modTimeGmt': '2023-05-03T00:44:26+0000',
#    'regTime': '2023-05-03T09:44:26+0900',
#    'regTimeGmt': '2023-05-03T00:44:26+0000',
#    'sympathyCount': 3,
#    'antipathyCount': 3,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': 'Iih1',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'pali****',
#    'maskedUserName': 'pa****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'default_economy',
#    'commentNo': '790710002863046957',
#    'parentCommentNo': '790710002863046957',
#    'replyLevel': 1,
#    'replyCount': 2,
#    'replyAllCount': 2,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683090875901,
#    'contents': '진짜 인생실패한 사람들이나 공무원 준비하더라 요새',
#    'userIdNo': '2RmDw',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'wjdt****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T14:14:35+0900',
#    'modTimeGmt': '2023-05-03T05:14:35+0000',
#    'regTime': '2023-05-03T14:14:35+0900',
#    'regTimeGmt': '2023-05-03T05:14:35+0000',
#    'sympathyCount': 2,
#    'antipathyCount': 2,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '2RmDw',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'wjdt****',
#    'maskedUserName': 'wj****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790690313323675988',
#    'parentCommentNo': '790690313323675988',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683072538948,
#    'contents': '9급 공무원은 할 사람만 하자~~ 고급인력들이 동사무소서 등본이나 발급하고 있다는건 국가적으로 손해다~',
#    'userIdNo': '2LJHa',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'mira****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T09:08:58+0900',
#    'modTimeGmt': '2023-05-03T00:08:58+0000',
#    'regTime': '2023-05-03T09:08:58+0900',
#    'regTimeGmt': '2023-05-03T00:08:58+0000',
#    'sympathyCount': 2,
#    'antipathyCount': 2,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '2LJHa',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'mira****',
#    'maskedUserName': 'mi****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'default_economy',
#    'commentNo': '790712623984279717',
#    'parentCommentNo': '790712623984279717',
#    'replyLevel': 1,
#    'replyCount': 1,
#    'replyAllCount': 1,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683093316890,
#    'contents': '왜 항상 가만히 있는 공무원만 머리채 잡고 닌리들이냐…ㅋㅋㅋ 부러워서 그러는 거임? 그게 아니면 도대체 왜? 남의 직업 까내리면서 본인이 더 우월하다고 느낀다면 참 불쌍한 인생들이다 얼마나 자존감이 없으면',
#    'userIdNo': '1B8ba',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'sk98****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T14:55:16+0900',
#    'modTimeGmt': '2023-05-03T05:55:16+0000',
#    'regTime': '2023-05-03T14:55:16+0900',
#    'regTimeGmt': '2023-05-03T05:55:16+0000',
#    'sympathyCount': 1,
#    'antipathyCount': 1,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '1B8ba',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'sk98****',
#    'maskedUserName': 'sk****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790708019578011979',
#    'parentCommentNo': '790708019578011979',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683089028258,
#    'contents': '9급공채 공무원은 그냥 중졸,고졸 기타 사회취약계층들만 할수 있게 못박아야 한다고 봄. 전문대,4년제대 졸업한 사람들이 하는건 너무 인력낭비라 생각함.',
#    'userIdNo': 'bGVpW',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'last****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T13:43:48+0900',
#    'modTimeGmt': '2023-05-03T04:43:48+0000',
#    'regTime': '2023-05-03T13:43:48+0900',
#    'regTimeGmt': '2023-05-03T04:43:48+0000',
#    'sympathyCount': 1,
#    'antipathyCount': 1,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': False,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': 'bGVpW',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'last****',
#    'maskedUserName': 'la****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False},
#   {'ticket': 'news',
#    'objectId': 'news018,0005477530',
#    'categoryId': '*',
#    'templateId': 'view_economy',
#    'commentNo': '790705234895700220',
#    'parentCommentNo': '790705234895700220',
#    'replyLevel': 1,
#    'replyCount': 0,
#    'replyAllCount': 0,
#    'replyPreviewNo': None,
#    'replyList': None,
#    'imageCount': 0,
#    'imageList': None,
#    'imagePathList': None,
#    'imageWidthList': None,
#    'imageHeightList': None,
#    'commentType': 'txt',
#    'stickerId': None,
#    'sticker': None,
#    'sortValue': 1683086435694,
#    'contents': '성동이형이 있는데 에듀윌 따위가 뭐라고 감히…',
#    'userIdNo': '34NGY',
#    'exposedUserIp': None,
#    'lang': 'ko',
#    'country': 'KR',
#    'idType': 'naver',
#    'idProvider': 'naver',
#    'userName': 'simo****',
#    'userProfileImage': None,
#    'profileType': 'naver',
#    'modTime': '2023-05-03T13:00:35+0900',
#    'modTimeGmt': '2023-05-03T04:00:35+0000',
#    'regTime': '2023-05-03T13:00:35+0900',
#    'regTimeGmt': '2023-05-03T04:00:35+0000',
#    'sympathyCount': 1,
#    'antipathyCount': 1,
#    'hideReplyButton': False,
#    'status': 0,
#    'mine': False,
#    'best': False,
#    'mentions': None,
#    'toUser': None,
#    'userStatus': 0,
#    'categoryImage': None,
#    'open': True,
#    'levelCode': None,
#    'grades': None,
#    'sympathy': False,
#    'antipathy': False,
#    'metaInfo': None,
#    'extension': None,
#    'translation': None,
#    'report': None,
#    'middleBlindReport': False,
#    'spamInfo': None,
#    'userHomepageUrl': None,
#    'defamation': False,
#    'hiddenByCleanbot': False,
#    'score': 0.0,
#    'ratings': None,
#    'following': False,
#    'managerLike': False,
#    'pick': False,
#    'attachmentList': [],
#    'reference': None,
#    'inspectionId': None,
#    'visible': True,
#    'userBlocked': False,
#    'idNo': '34NGY',
#    'manager': False,
#    'deleted': False,
#    'blindReport': False,
#    'expose': True,
#    'serviceId': None,
#    'maskedUserId': 'simo****',
#    'maskedUserName': 'si****',
#    'blind': False,
#    'secret': False,
#    'profileUserId': None,
#    'exposeByCountry': True,
#    'validateBanWords': False,
#    'containText': True,
#    'virtual': False,
#    'originalStatus': 0,
#    'anonymous': False}],
#  'pageModel': {'page': 1,
#   'pageSize': 100,
#   'indexSize': 10,
#   'startRow': 1,
#   'endRow': 100,
#   'totalRows': 259,
#   'startIndex': 0,
#   'totalPages': 3,
#   'firstPage': 1,
#   'prevPage': 0,
#   'nextPage': 2,
#   'lastPage': 3,
#   'current': None,
#   'threshold': None,
#   'moveToLastPage': False,
#   'moveToComment': False,
#   'moveToLastPrev': False},
#  'morePage': {'prev': '10000o90000op06guicil48ars',
#   'next': '10000000000010609lm298q3ng',
#   'start': '10000ii0000lb0609e8tf0angw',
#   'end': '0zik0zb0000020609gngbg5thf'},
#  'exposureConfig': {'reason': None, 'status': 'COMMENT_ON'},
#  'count': {'comment': 259,
#   'reply': 126,
#   'exposeCount': 246,
#   'delCommentByUser': 16,
#   'delCommentByMon': 0,
#   'blindCommentByUser': 0,
#   'blindReplyByUser': 0,
#   'total': 385},
#  'listStatus': 'all',
#  'sort': 'FAVORITE',
#  'bestList': []}

# %%
temp['result']['commentList'][1]['contents']
# Out:
# '공무원을 왜 하냐\n월급도 적지 연금도 바닥이고\n\n자기 발전도\n 없구'

# %%
for i in temp['result']['commentList'] :
    print(i['contents'])
# Out:
# 옛날 80~90년대는 공무원 하라고해도 하는사람 없었음.  얼마나 하는 사람이 없으면 읍,면,동장이 적합한 인재있으면 추천해줘서 공무원되고 그런 시절이 있었지... 소개팅이나 맞선 시장에서 쳐주지도 안했다더라.  어떻게보면 정상적으로 돌아가고 있는거
# 공무원을 왜 하냐
# 월급도 적지 연금도 바닥이고
#
# 자기 발전도
#  없구
# 공무원합격은 귄성0
# 뭘 어떻게 했길래 빚이 쌓이냐?? 그간 공시생들 돈 쪽쪽 빨았을텐데???
# 공무원은 하면 안된다.일이 편한것도 아니고, 잦은 부서 이동으로 10년간 신규처럼 일해야 된다. 민선제의 혼돈으로 인해 시군구청장이 재선을 위해 쓸데없는 일 엄청 만든다.그리고 각 시의원들이 보좌관 둘 수 있어서 공무원한테 자료요구 엄청나고, 스마트한 시민과 악성 민원으로 항상 시달리며 30년 해도 월 5~600  가량 이다. 누군가에겐 크지만 누군가에겐 10년차면 가져갈 금액이지. 마지막으로 남은연금도 65세 이상 돼야 받을수 있고 ,정년은 60세라서 5년간 손 빨아야됨. 연금은 국민연금
# 유명강사들 다른학원 이직하는거보고 뭔가 쎄한 느낌들던데..역쉬.
# 공무원보다 국회의원놈들 월급을 최저시급으로 깎아야된다.
# 월급 500받는 사람처럼 업무, 욕받이 시키는데 월급은 최저임금주고 남들은 몇억씩 챙겨나가는 퇴직금조차 못받고 연금은 개박살나서 국민연금이랑 별차이도 없는수준까지 내려왔는데 도대체 아무런 메리트가 없는 직업인데 할 이유가 없잖아...
# 공무원 요즘 하고 싶어 하겠냐? 그나마 바라볼 공무원연금도 반토막 났는데. 차라리 국민연금을 달라 하는 공무원들이 태반이다. 박봉이고. 그렇다고 워라벨을 챙기나? 칼퇴하는 공무원은 일부고, 일에 시달려서 늦게 퇴근한다. 인수인계도 잘 안 되고, 전 근무자가 다음 근무자 죽어보라고 컴퓨터 가져가는 경우도 있다. 거기다 철밥통이라고 윗사람도 안 잘리는데 그 사람이 진상이면, 그냥 계속 봐야 한다. 거기다 군대마냥 상하관계 심하고. 그러니 공무원 시험 힘들게 하고 몇 달 다니다 나가거나, 버티다 힘들어서 자살하는 경우가 많다. 짠하다.
# 문재인 정권때 공무원 수 엄청 늘리더니 결국 이꼴 남
# 어차피 별볼일 없는 허수들만 빠진거고 경쟁은 여전히 치열함ㅋㅋ
# 매출에 비해 마케팅 과하게하는 특히 유명연예인에 의존하는 기업과 제품은 걸러야한다. 연예인, 인플루언서, 방송ppl에 놀아나지마라.
# 그래도 공무원이 젤 속편함..
# 내실없이 너무 사업을 무리해서 확장해나가니 이런 사단이 벌어진 거임. 딱 공인중개사와 주택관리사만 하고 다른 것은 손대지 말았어야 함. 다른 자격증이나 공무원 합격자들 대부분 에듀윌로는 공부 잘 안함.
# 공기업  일반회사보다  일은힘들고  월급은  적게주니  점점인기가  없어진다  그보상으로  퇴직후  연금을  받는건데  그것도  깍으라고  난리고  점점
# 의욕이  없어 질수 밖에없다
# 공무원이지만 진짜 할 게 아닙니다. 박봉에 책임은 엄청많고 얼마나 제약이 많은지요.
# 공무원이라는 직업 그렇게 좋은 직업이 아니다. 첫번째 늘 야근을 하지만 초과근무 수당을 정당하게 받지 못한다. 일반공무원 경우 일일 4시간 적용되기 때문에 휴일날 초과근무을 4시간이상 하여도 동일하게 4시간만 인정되고 지급받는다. 두번째 공무원 연금은 각 개인 급여 9.8% 그리고 각 소득세, 건강보험 등 공제된다. 그럼 실수령액은 얼마 일 것 같습니까?.  공무원 연금 이제 국민연금 수준으로 노후대책이 되지 않는다. 모두다 옛말이다.
# 편의점 야간 알바가 훨씬 많이 버는데 누가 공무원을 함ㅋㅋ
# 1000명에게 물어 봤더니....중소기업 갈래...공무원 할래...질문 했습니다...결과는 중소기업 17.5%  공무원 78.4 %  기타 4.1%  로 나왔습니다  ..그래도 공무원을 선택합니다
# 권성동 한테 원생 다 뺐겨서 망한듯
# 공무원하면 먹고살기 힘들어요
# 권성0한테 부탁하면 다 되는데 뭐하러 에듀윌 다니겠어~~
# 서X석만 돈 벌었네 ㅋㅋ
# 열심히 공부해서 자격증 취득해도 돈을 버는 것은 자격증 학습지 회사....자격증을 취득해도 돈은 안된다.
# 최근 열심히 공부해서 공인중계사 합격했지만 돈은 벌지 못하고 결론은 저런 교육 관련 회사들만 돈을 벌었지....그러니까 사교육을 시켜도 돈을 버는 것은 관련 종사자들 뿐이고 대다수 아이들은 일부를 제외하고 저런 회사의 돈벌이 수단일 뿐이다.
# 상관 눈치봐야 하고 9급으로 시작하면 평생을 지방에서 상전 눈치보다 끝남. 잘돼야 5급 사무관인데 그러기 위해 시장 군수 눈치까지 봐야하고 과장 줄 서야하고.
# 그런들 엄청난 보상이 있는 것도 아님.
# 공노비라고 봐도 무방할 지경.
# 동사무소 서류떼러갔는데, 서류하나떼는데 겁나느리고 불친절. 옆자리에선 악성민원 받고 있던데,
# 분위기도 진짜안좋고, 월급도 너무적고, 연금박살나고
# 젊은친구들이 잠깐하다가 그만두는이유를 느꼈음
# 취업률을 공무원채용으로 매꿨다 했을때 5년동안 또 뭘 돌려막기 했을까 싶더라
# 공무직에 치이고 업무 떠넘기는 갑질과 온갖 민원인 갑질에 치이고 잘못된 관행이 법 위에 있고 조직 쇄신해야 할 감사도 개판이고 갑질 신고도 무혐의 처분이 대부분이고 저임금에 미래 보장 안되고 자부심과 책임성은 조금도 가질 수 없는 조직이 공무원 조직인 거 같은데 그러니 공무원 신규자 이직률 갈수록 높아지고 있고 좀 더 자부심 가질 좋은 조직으로 갈 수있는 능력만 있다면 누가 공무원 하려고 할까.
# 2009년 이후 임용된 자 공무원 연금 = 국민연금
# 에듀웰이 망한건 권성동때문 아니여?
# 잘난넘. 말단꽁원하면 국가적 개인적 손실이다만,  그저 . 특별히 잘난거 없는.  평범한 넘. 그래도  무시안당하고. 큰. 시련없이  . 한세상살아가기는. 공무원 만큼 좋은직업 없수다 ?
# 공뭔  사회 특유의 갑질만연, 상명하복,위계,  권위주의,
# 일많고 박봉에  골병드는  공뭔인데 요즘MZ세대가  누가  오겠냐
# 10년전만해도 9급 서울시 공무원 vs 변호사 이질알 떠는애들이 커뮤니티에 상당수 있었다ㅎㅎ
# 자기가 공부하는 9급 공무원에대해 박봉이라고 조금이라도 안좋은 소리하면
# 아주 부모욕까지 꺼내던 멍청이들이었지
# 걔들이 지금 30대다
# 그 멍청이들이 또 문재인때 영혼까지 끌어다가 집을 산 애들이지ㅎㅎ
# 쉽게말해 이명박 키즈 일베충 초창기 애들이야
# 당시엔그만큼 시야도좁고 취업문도 좁고 먹고살게 없었다는거지
# 공직인기가 떨어진 지금이 오히려 다행이야
# 중소기업 수준도 안되는 박봉에 하는일은 고졸수준이면 가능한
# 실체를 알았으니 요새 20대들이 똑똑한거
# 여기 자꾸 공무원 매리트 없다 떠드는데 실상이나 알고 해라  내가 이런것  당해 아는데 공장 생활 회사 생활 그리 편한줄 아냐 나갈려면 나가라 하는게 현실판   죽으나사나 공무원이 쵝고다   자꾸 공무뭔 도전하는데 방해세력에 휘둘리지 말고 도전할 자들은 이럴때 오히려 더 기회다 도전
# 여성에겐 좋은 직업이고, 남성에간 다소 박한 직업임.
# 공무원 월그이. 조호조무사보다. 적다
# 월급도 박봉인데 투잡도 안된다더만요
# 하다못해 아파트 동대표도 못한다고 함
# 월급은 코딱지에 퇴직금도 없고 자녀학자금도 안대주고 연금은 팍줄고 민원은 개같이 많고 인기 떨어지는거 당연하지
# 저출산 인구가 취업시장 나올떄쯤이면 과거처럼 공무원  아무나 다 근무할수 있을듯 공무원 바겐세일임
# 일만많고 봉급적고 연금도 형편없는데 누가가나
# 공무원 합격은 감성돔이지
# 공무원들 불쌍하다..어이없는 대우와 월급..정년과 연금 믿고 다닌다고 하지만 이건 인권침해에 가까운 대우지..
# 권모씨를 광고모델로 영입해라. 꽃아주기 전문이신분 있잖아.
# 에듀월보단 공단기를 많이 선택하지 않나? 에듀월 교재를 살펴보니 여러모로 공단기보다 열세던데... 공무원 인기가 떨어져서 에듀월이 타격을 받았다기 보다는, 경쟁에서 밀린 듯 보입니다.
# 나라꼴 보니 imf 시즌2  온다 인기는 다시 올라갈것이다
# 공무원이 꿈인 나라는 망하게 되어있다
# 야,,솔직히 편의점 알바 몇개해도,,더벌어,,,공무원 보수 수준 최악이야,,,수십년 일하고 받는돈도,,,그냥 그래,,장사해라,,차라리 ,,,,공무원 하면,,,아반떼 타기도 힘들어,,,,공무원 최악이야, 민원도 많고,,일도 많고,,감사에 툭하면,,,보고서에,,,선거때도 끌려가고 산불조심에도 끌려가고,,온갖,,잡일 민원,,자살하는 사람이 왜 나오는데 하지마라,
# 지금 누가 공뭔 될려고 하지???????????????????????????
# 나라가 정상화되었다는 증거입니다. 젊은이들 희망직업 1위가 공무원인 나라는 망조가 단단히 든 나라입니다.
# 그래도 합격컷은 예나 지금이나 똑같이 높더라. 응시과목 대폭 대편되면서 어중이떠중이 응시생들 싹다 원서제출도 못하게 막은 게 큰듯.
# 노령인구 많으니까 노인대학 이나 만드세요
# 잘 나가던 에듀윌도 어려운 거 보니 진짜 경제가 어렵긴 어렵나보네.
# 경기 한파 준비해야 할 듯~
# 다들 화이팅하시고 에듀윌 잘 극복하길 바랍니다.
# 공무원 인기가 문제가 아니라 회사에 도둑놈이 많으면 저렇게됨
# 일감 몰아주기...
# 유명강사 빠져 나간다는건 망하는 서막,,
# 문죄인이가 공무원 20만명을 늘려놨다고 하니...공무원지옥 만든 거지..이게 다 문죄인 덕분이다
#
# 공무원 합격은 권성돔..
# 그동안 공무원이 인기있던게 이상한거지
# 능력있으면 공무원보다 더 탄탄한 삶을 살수있는데 왜 구지 공무원의 길을 선택해서 본인 인생의 찬란한 앞길을 제한을 걸 필요가..
# 중국이 왜 잘나가는지 알아? 20대 창업의지와 창업건수가 세계최고라서 그래... 본받아라
# 공무원 시험 합격은 권성동. 에듀윌이 안 망할 수 없지.
# 화살코만 광고출연비로  빌딩샀네 ㅋㅋ
# 요즘 젊은이들은 공무원 힘들게 붙어도 그만 둔다. 괴리감이 드는건지..  하긴 좋은대학 나오고 똑똑한 인재들이 7급아닌이상 9급공무원부터 시작하기 힘들듯
# 유재석이도 잘한거 없다
# 자꾸 거론되는거보니 좋은직업인갑다~ ㅋㅋ
# 근데 나이들고 연봉늘어나면 부러울듯... 안정적이고
# 드디어 나라가 정상적으로 돌아가네요...ㅠㅠ
# 제대로 사회가 돌아가고 있다고 난 믿고있다.
#
# 생산성이 없는. 공무원에 똑똑한 사람들이 몰린다는 건
#
# 더이상 그 사회가 미래가 없다는 뜻이고
#
# 생산성 높고. 치열하게 사는 사람들이 더 많이 받는건 당연하다고 본다
#
# ㄱㅅ동땜에 말아드심
# 공무원 합격은 권성동이지
# 권성동 통하면 되징ㅋㅋ
# 문재인 공무원 많이 뽑을때 부터 알아봤다 ㅉㅉ
# 90년 중반에도 공무원 알아주지도 않았다.. 공대 나와 대기업 취업 하여 결혼 하고 작은 아파트 사고 알콩달콩 살라고 담임이 자주 이야기 했지… 그 정도면 성공 한 것이라고…
# 이일 육두문자 나오네. 따닥따닥 붙어앉아서 긴밀히 물어보며 업무해야해서 성깔죽이고 얌전히 일해야하고 폐쇄적이고 상명하복 먼 자기주장 못내세우는 분위기. 일이 육체적으로 편하다 이거하나땜에 그냥 자존감과 뇌없이 출근
# 노조고시는 없나?
# 공무원보다 요즘은 민노가 대세잖아.
# 민노고시나 한노고시.
# 아마 대가리 터지게 지원할텐데.
# 꽃보직에 일도 안하고 연봉은 억대연봉.
# 이제 세상이 제대로 돌아가내ㅔ
# 차라리 똥을 퍼면 펐지 면서기는 안한다였는데 세월이 지나 갑자기 인기가 많아지더니 다시 없어졌네 역시 공무원이라는 것도 잠깐 떳다 사라지는 테마주 같은 느낌임
# 성동이가 더 빠르니. ㅋㅋ
# 나라를 개판 만들어 놓은놈 잡으러가자
# 저런데 안가도 선동이가 뽑아주잖아? 왜 비싼돈 들임?
# 한국사 찟 대는 강사들 전면에 내세우고 문씨 찬양하면서 몇 바퀴 돌리면 개 딸및 찟딸들이 유툽에서 홍보해주고 하면 금방 회복된다. 해커스 봐라.  지하찰 광고 보았느냐 ?
#
# 공무원 밖에 없나? 주택관리사, 공인회계사, 공인중계사도 있다. 헤쳐나가야지
#
# 공무원 절반줄이고 국회의원 100 명으로 줄여야 나라가 산다
# 이게 다 권성동 때문이다
# 그래도 공무원이  췩오
# 일 자체가 성취욕이 전혀 없는 복지부동, 무사안일의 전형이니 있던 사람도 나가지. 20대초중반에 들어와 60대까지 자아를 깨우칠 수 없는 이런 일은 한다면 그 인생도 참 답답하지. 뭐 다른 일이라고 다를까마는 공무공직사회의 경직성, 행정주의, 개성없음은 좀 심각하긴 하지. 공직사회도 개혁해야 함.
# 서경석만이 승자구만... 공무원안하고 공무원시험 권유해서 성공한 1인
# Imf 전만 해도 대학나와서 공무원하면 동네에서 욕먹고 그랬지
# 에듀윌 안 듣고 다 공단기나 메가 들으니까요
# 재앙이가 공무원 역대급으로 뽑을땐 우리제인이 잘한다했겠지 좌파들의 단세포는 사회여러분야에서 망조로 드러나고 있다
# 고3 학생이 한때 100만명이었다가, 지금은 30만명.  앞으로 10만명이 얼마 안남았다.  출생율 0.7명의 한국여자가 그저 한심하고 대단하다
# 진짜 인생실패한 사람들이나 공무원 준비하더라 요새
# 9급 공무원은 할 사람만 하자~~ 고급인력들이 동사무소서 등본이나 발급하고 있다는건 국가적으로 손해다~
# 왜 항상 가만히 있는 공무원만 머리채 잡고 닌리들이냐…ㅋㅋㅋ 부러워서 그러는 거임? 그게 아니면 도대체 왜? 남의 직업 까내리면서 본인이 더 우월하다고 느낀다면 참 불쌍한 인생들이다 얼마나 자존감이 없으면
# 9급공채 공무원은 그냥 중졸,고졸 기타 사회취약계층들만 할수 있게 못박아야 한다고 봄. 전문대,4년제대 졸업한 사람들이 하는건 너무 인력낭비라 생각함.
# 성동이형이 있는데 에듀윌 따위가 뭐라고 감히…
